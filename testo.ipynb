# %%
from pymongo import *

connection = "mongodb://bouman:80um4N!@ec2-15-188-255-64.eu-west-3.compute.amazonaws.com:27017/"
client = MongoClient(connection)
db = client.get_database ('media_analysis')
col = db["articles"]

# %%
total_docs = col.count_documents({})
print (col.name, "contains", total_docs, "documents.")
print("done")
# Out:
# articles contains 2954784 documents.
# done

# %%
resp = db.articles.find().limit(1)
for doc in resp:
    print(doc)
# Out:
# {'_id': ObjectId('5ec760320e5c92500d004aec'), 'url': 'https://plus.lesoir.be/302284/article/2020-05-22/la-famille-du-journaliste-saoudien-tue-dans-le-consul-darabie-saoudite-istanbul', 'meta': {'source': {'name': 'lesoir.be', 'feed_url': 'https://plus.lesoir.be/rss/81853/cible_principale_gratuit', 'feed_title': 'La une', 'country': 'BE', 'language': 'fr'}, 'feedparser': {'title': 'La famille du journaliste saoudien tué dans le consul d’Arabie saoudite à Istanbul «pardonne» aux assassins', 'summary': 'Jamal Khashoggi, critique du régime saoudien après en avoir été proche, a été assassiné et son corps découpé en morceaux le 2 octobre 2018', 'publication_date': datetime.datetime(2020, 5, 22, 4, 49, 17)}, 'newspaper3k': {'authors': [], 'summary': '', 'top_image': 'https://plus.lesoir.be/sites/default/files/dpistyles_v2/ena_16_9_extra_big/2020/05/22/node_302284/27555231/public/2020/05/22/B9723524265Z.1_20200522064917_000+GBHG20GPF.1-0.jpg?itok=KHWta-0l1590122967'}}, 'date': datetime.datetime(2020, 5, 22, 4, 49, 17), 'text': 'Jamal Khashoggi, critique du régime saoudien après en avoir été proche, a été assassiné et son corps découpé en morceaux le 2 octobre 2018\n\nLes enfants de Jamal Khashoggi, journaliste saoudien assassiné en octobre 2018 dans le consulat d’Arabie saoudite à Istanbul, ont annoncé vendredi qu’ils pardonnaient aux tueurs de leur père.\n\n« Nous, les fils du martyr Jamal Khashoggi, annonçons que nous pardonnons à ceux qui ont tué notre père », a écrit sur Twitter Salah Khashoggi, fils de l’ancien journaliste du Washington Post.\n\nUn meurtre odieux\n\nJamal Khashoggi, critique du régime saoudien après en avoir été proche, a été assassiné et son corps découpé en morceaux le 2 octobre 2018 dans le consulat d’Arabie saoudite à Istanbul où il s’était rendu pour récupérer un document.', 'title': 'La famille du journaliste saoudien tué dans le consul d’Arabie saoudite à Istanbul «pardonne» aux assassins', 'textrazor_response': {'response': {'coarseTopics': [{'id': 0, 'label': 'Politics', 'wikiLink': 'http://en.wikipedia.org/Category:Politics', 'score': 1}, {'id': 1, 'label': 'Violence', 'wikiLink': 'http://en.wikipedia.org/Category:Violence', 'score': 0.9795}, {'id': 2, 'label': 'Culture', 'wikiLink': 'http://en.wikipedia.org/Category:Culture', 'score': 0.7495}, {'id': 3, 'label': 'Law', 'wikiLink': 'http://en.wikipedia.org/Category:Law', 'score': 0.3354}, {'id': 4, 'label': 'Arts', 'wikiLink': 'http://en.wikipedia.org/Category:Arts', 'score': 0.305}, {'id': 5, 'label': 'Belief', 'wikiLink': 'http://en.wikipedia.org/Category:Belief', 'score': 0.2447}], 'language': 'fre', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Jamal Khashoggi', 'wikiLink': 'http://en.wikipedia.org/Jamal_Khashoggi', 'score': 1, 'wikidataId': 'Q1262052'}, {'id': 1, 'label': 'Saudi Arabian people murdered abroad', 'wikiLink': 'http://en.wikipedia.org/Category:Saudi_Arabian_people_murdered_abroad', 'score': 1}, {'id': 2, 'label': 'Middle East', 'wikiLink': 'http://en.wikipedia.org/Category:Middle_East', 'score': 1, 'wikidataId': 'Q7204'}, {'id': 3, 'label': 'Saudi Arabian journalists', 'wikiLink': 'http://en.wikipedia.org/Category:Saudi_Arabian_journalists', 'score': 1}, {'id': 4, 'label': 'Saudi Arabian Muslims', 'wikiLink': 'http://en.wikipedia.org/Category:Saudi_Arabian_Muslims', 'score': 1}, {'id': 5, 'label': 'Saudi Arabia–Turkey relations', 'wikiLink': 'http://en.wikipedia.org/Category:Saudi_Arabia–Turkey_relations', 'score': 1, 'wikidataId': 'Q1033131'}, {'id': 6, 'label': 'Assassinated journalists', 'wikiLink': 'http://en.wikipedia.org/Category:Assassinated_journalists', 'score': 1}, {'id': 7, 'label': 'Assassinated Saudi Arabian people', 'wikiLink': 'http://en.wikipedia.org/Category:Assassinated_Saudi_Arabian_people', 'score': 1}, {'id': 8, 'label': 'Politics of Saudi Arabia', 'wikiLink': 'http://en.wikipedia.org/Category:Politics_of_Saudi_Arabia', 'score': 1, 'wikidataId': 'Q1837899'}, {'id': 9, 'label': 'Saudi Arabian people', ' ...

# %%
fr_news = col.find({'meta.source.language': 'fr'})

# %%
fr_news = db.articles.find({}, fr_query).limit(3)

# %%
nl_news = col.find({'meta.source.language': 'nl'}).limit(5)
for i in nl_news:
    print(i)
# Out:
# {'_id': ObjectId('5ec8066f656ebc99880e73ae'), 'url': 'https://vrtnws.be/p.xV5bZwAjN', 'date': datetime.datetime(2020, 5, 22, 17, 0), 'meta': {'source': {'name': 'vrt.be', 'feed_url': 'https://www.vrt.be/vrtnws/nl.rss.articles.xml', 'feed_title': 'articles', 'country': 'BE', 'language': 'nl'}, 'feedparser': {'title': 'KU Leuven boekt hoopvolle resultaten in zoektocht naar\ncoronavaccin: "We zijn op de goede weg"', 'summary': 'Professor Johan Neyts van de KU Leuven heeft samen met zijn team goede resultaten geboekt in de zoektocht naar een vaccin tegen het coronavirus. Uit de eerste proeven op hamsters blijkt dat één van de vaccins die ze testen, goede bescherming biedt. De tests moeten nu nog herhaald worden, en daarna kan het kandidaatvaccin op mensen getest worden. "We hebben goede hoop dat we op de goede weg zijn", vertelt hij aan VRT NWS. Wereldwijd zijn er ruim 100 kandidaat-vaccins die onderzocht worden.', 'published_parsed': datetime.datetime(2020, 5, 22, 17, 0)}, 'newspaper3k': {'authors': ['Vrt Nws', 'Koen Wauters', 'Pieterjan Huyghebaert'], 'summary': '', 'top_image': 'https://images.vrt.be/vrtnws_share/2020/05/22/04ada047-9c22-11ea-aae0-02b7b76bf47f.jpg', 'date': datetime.datetime(2020, 5, 22, 17, 0)}}, 'text': 'Zonder al te technisch te worden, werkt het als volgt: In januari is de genetische code van het coronavirus gepubliceerd. Ook de genetische code van het gele koorts-vaccin is al langer bekend. Het team van Neyts plakt een stukje van de genetische code van het coronavirus in de code van dat vaccin tegen gele koorts.\n\n"Zo hopen we dat we met dat nieuwe vaccin afweer opbouwen tegen het coronavirus én dat het mogelijk zal zijn om met één spuitje een heel lange immuniteit te doen ontstaan", legt Neyts uit. Ze maken daarvoor gebruik van de CRISPR-techniek.', 'title': 'KU Leuven boekt hoopvolle resultaten in zoektocht naar coronavaccin: "We zijn op de goede weg"', 'textrazor_response': {'response': {'coarseTopics': [{'id': 0, 'label': 'Health', 'wikiLink': 'http://en.wikipedia.org/Category:Health', 'score': 1}, {'id': 1, 'label': 'Science', 'wikiLink': 'http://en.wikipedia.org/Category:Science', 'score': 0.9234}, {'id': 2, 'label': 'Nature', 'wikiLink': 'http://en.wikipedia.org/Category:Nature', 'score': 0.7429}, {'id': 3, 'label': 'Culture', 'wikiLink': 'http://en.wikipedia.org/Category:Culture', 'score': 0.5908}, {'id': 4, 'label': 'Technology', 'wikiLink': 'http://en.wikipedia.org/Category:Technology', 'score': 0.479}, {'id': 5, 'label': 'Arts', 'wikiLink': 'http://en.wikipedia.org/Category:Arts', 'score': 0.3209}], 'language': 'dut', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Biology', 'wikiLink': 'http://en.wikipedia.org/Category:Biology', 'score': 1, 'wikidataId': 'Q420'}, {'id': 1, 'label': 'Medical specialties', 'wikiLink': 'http://en.wikipedia.org/Category:Medical_specialties', 'score': 0.9176, 'wikidataId': 'Q930752'}, {'id': 2, 'label': 'Clinical medicine', 'wikiLink': 'http://en.wikipedia.org/Category:Clinical_medicine', 'score': 0.9127}, {'id': 3, 'label': 'Health sciences', 'wikiLink': 'http://en.wikipedia.org/Category:Health_sciences', 'score': 0.9106, 'wikidataId': 'Q843601'}, {'id': 4, 'label': 'Immunology', 'wikiLink': 'http://en.wikipedia.org/Category:Immunology', 'score': 0.848, 'wikidataId': 'Q101929'}, {'id': 5, 'label': 'Life sciences', 'wikiLink': 'http://en.wikipedia.org/Category:Life_sciences', 'score': 0.8466, 'wikidataId': 'Q864928'}, {'id': 6, 'label': 'Medicine', 'wikiLink': 'http://en.wikipedia.org/Category:Medicine', 'score': 0.7911, 'wikidataId': 'Q11190'}, {'id': 7, 'label': 'Genetics', 'wikiLink': 'http://en.wikipedia.org/Genetics', 'score': 0.6519, 'wikidataId': 'Q7162'}, {'id': 8, 'label': 'Immune system', 'wikiLink': 'http://en.wikipedia.org/Immune_system', 'score': 0.6354, 'wikidataId': 'Q1059'}, {'id': 9, 'label': 'Organisms', 'wikiLink': 'http://en.wikipedia.org/Category:Organisms', 'score': 0.6008, 'wikidataId': 'Q7239'}, {'id': 10, 'label': 'Veterinary med ...
# {'_id': ObjectId('5ec8066fac7298b94a3cf3b9'), 'url': 'https://vrtnws.be/p.EeR17mpDp', 'date': datetime.datetime(2020, 5, 22, 3, 56, 28), 'meta': {'source': {'name': 'vrt.be', 'feed_url': 'https://www.vrt.be/vrtnws/nl.rss.headlines.xml', 'feed_title': 'headlines', 'country': 'BE', 'language': 'nl'}, 'feedparser': {'title': 'Liveblog: Jongerenkampen mogen doorgaan deze zomer en meer kinderen kunnen naar school, volg LIVE "Het Journaal"', 'summary': 'De zomerkampen en speelpleinwerkingen krijgen het licht op groen vanaf 1 juli, maar met de beperking van maximaal 50 personen. Minister van Jeugd Benjamin Dalle juicht de beslissing van het Overlegcomité toe op een persconferentie. De Vlaamse overheid en onderwijssector vragen aan de Nationale Veiligheidsraad om alle kleuterscholen volledig te openen vanaf 2 juni. Meer kinderen uit het lager en secundair onderwijs zouden de lessen moeten hervatten. In de voorbije 24 uur zijn 56 mensen in ons land opgenomen in het ziekenhuis met een coronabesmetting, 26 mensen zijn overleden. De algemene dalende trend zet zich dus door. Volg hier alle updates in onze liveblog.', 'published_parsed': datetime.datetime(2020, 5, 22, 3, 56, 28)}, 'newspaper3k': {'authors': ['Vrt Nws', 'Kathleen Heylen', 'Ludwig De Wolf', 'Joris Truyts', 'Vlaams Minister Van Jeugd Benjamin Dalle', 'Cd V', 'Vlaams Minister Van Onderwijs Ben Weyts In', 'De Wereld Vandaag', 'Katrien Van Laere', 'Specialist Kleuteronderwijs In'], 'summary': '', 'top_image': 'https://images.vrt.be/vrtnws_share/2020/05/18/58185f55-9910-11ea-aae0-02b7b76bf47f.jpg', 'date': datetime.datetime(2020, 5, 22, 3, 56)}}, 'text': 'Het federale Overlegcomité heeft een handleiding over de organisatie van jeugdactiviteiten goedgekeurd. Na overleg met experts is beslist dat buurtspeeltuinen in de open lucht vanaf 27 mei geopend mogen worden voor kinderen tot en met twaalf jaar.\n\nZomerkampen en speelpleinwerkingen met of zonder overnachting mogen vanaf 1 juli doorgaan in zogenaamde contactbubbels van maximaal 50 personen. Jongeren en begeleiders ouder dan 12 jaar moeten de veiligheidsafstand zoveel mogelijk blijven respecteren.\n\nOok jeugdhuizen kunnen hun activiteiten weer opstarten voor contactbubbels van maximaal 50 jongeren.', 'title': 'Liveblog: Jongerenkampen mogen doorgaan deze zomer en meer kinderen kunnen naar school, volg LIVE "Het Journaal"', 'textrazor_response': {'response': {'coarseTopics': [{'id': 0, 'label': 'Politics', 'wikiLink': 'http://en.wikipedia.org/Category:Politics', 'score': 1}, {'id': 1, 'label': 'Law', 'wikiLink': 'http://en.wikipedia.org/Category:Law', 'score': 0.7004}, {'id': 2, 'label': 'Culture', 'wikiLink': 'http://en.wikipedia.org/Category:Culture', 'score': 0.5571}, {'id': 3, 'label': 'Technology', 'wikiLink': 'http://en.wikipedia.org/Category:Technology', 'score': 0.4061}, {'id': 4, 'label': 'Education', 'wikiLink': 'http://en.wikipedia.org/Category:Education', 'score': 0.3728}, {'id': 5, 'label': 'Violence', 'wikiLink': 'http://en.wikipedia.org/Category:Violence', 'score': 0.3644}], 'language': 'dut', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Human activities', 'wikiLink': 'http://en.wikipedia.org/Category:Human_activities', 'score': 0.8231}, {'id': 1, 'label': 'Government', 'wikiLink': 'http://en.wikipedia.org/Category:Government', 'score': 0.7367, 'wikidataId': 'Q7188'}, {'id': 2, 'label': 'Politics', 'wikiLink': 'http://en.wikipedia.org/Category:Politics', 'score': 0.5336, 'wikidataId': 'Q7163'}, {'id': 3, 'label': 'Social institutions', 'wikiLink': 'http://en.wikipedia.org/Category:Social_institutions', 'score': 0.5068, 'wikidataId': 'Q178706'}, {'id': 4, 'label': 'Law', 'wikiLink': 'http://en.wikipedia.org/Category:Law', 'score': 0.4358, 'wikidataId': 'Q7748'}, {'id': 5, 'label': 'Social issues', 'wikiLink': 'http://en.wikipedia.org/Category:Social_issues', 'score': 0.3759, 'wikidataId': 'Q1920219'}, {'id': 6, 'label': 'Public sphere', 'wikiLink': 'http://en.wikipedia.org/Category:Public_sphere', 'sc ...
# {'_id': ObjectId('5ec8066f7db77e056c19b7c3'), 'url': 'https://vrtnws.be/p.ZPL9XW6JR', 'date': datetime.datetime(2020, 5, 22, 13, 42, 28), 'meta': {'source': {'name': 'vrt.be', 'feed_url': 'https://www.vrt.be/vrtnws/nl.rss.limburg.xml', 'feed_title': 'limburg', 'country': 'BE', 'language': 'nl'}, 'feedparser': {'title': 'Mucopatiënt Ine Hendrikx: "Of mijn longen corona zouden aankunnen, is niet bepaald een vrolijk vraagstuk"', 'summary': 'Mucopatiënt Ine Hendrikx uit Peer hoopt dat mensen na het COVID-19-tijdperk bepaalde gewoontes zullen onthouden. Als mucopatiënt is ze extra op haar hoede voor het coronavirus en wat dat met haar longen kan doen. Terwijl de meeste mensen de voorbije maanden maar moeilijk konden wennen aan de strenge lockdownmaatregelen, zijn die voor de dertiger haast schering en inslag.', 'published_parsed': datetime.datetime(2020, 5, 22, 13, 42, 28)}, 'newspaper3k': {'authors': ['Vrt Nws', 'Lien Vande Kerkhof', 'Mucopatiënt Ine Hendrikx'], 'summary': '', 'top_image': 'https://images.vrt.be/vrtnws_share/2020/05/22/07d87995-9c2d-11ea-aae0-02b7b76bf47f.jpg', 'date': datetime.datetime(2020, 5, 22, 13, 42)}}, 'text': 'Door een gendefect hebben mucopatiënten last van abnormaal taai slijmvlies. Dat slijm hoopt zich op in de longen, waardoor er een zware hoest, ontstekingen en permanente longschade kan ontstaan. Terwijl de longcapaciteit van een leeftijdsgenoot varieert tussen de 90 en de 100 procent, bedraagt die bij Ine vandaag amper 30 procent. “Voor wie net als mij lijdt aan mucoviscidose, ook bekend als de taaislijmziekte, is het altijd opletten geblazen”, steekt de Peerse van wal. “Iedereen die hoest en proest kan gevaarlijk zijn. Zelfs een klein griepje of een minimale longontsteking kunnen uitdraaien op een ramp. Of mijn longen het coronavirus zouden aankunnen, is dus niet bepaald een vrolijk vraagstuk.”', 'title': 'Mucopatiënt Ine Hendrikx: "Of mijn longen corona zouden aankunnen, is niet bepaald een vrolijk vraagstuk"', 'textrazor_response': {'response': {'coarseTopics': [{'id': 0, 'label': 'Health', 'wikiLink': 'http://en.wikipedia.org/Category:Health', 'score': 1}, {'id': 1, 'label': 'Science', 'wikiLink': 'http://en.wikipedia.org/Category:Science', 'score': 0.7014}, {'id': 2, 'label': 'Nature', 'wikiLink': 'http://en.wikipedia.org/Category:Nature', 'score': 0.6387}], 'language': 'dut', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Anatomy', 'wikiLink': 'http://en.wikipedia.org/Category:Anatomy', 'score': 1, 'wikidataId': 'Q514'}, {'id': 1, 'label': 'RTT', 'wikiLink': 'http://en.wikipedia.org/Category:RTT', 'score': 1}, {'id': 2, 'label': 'Diseases and disorders', 'wikiLink': 'http://en.wikipedia.org/Category:Diseases_and_disorders', 'score': 1, 'wikidataId': 'Q12136'}, {'id': 3, 'label': 'Respiratory diseases', 'wikiLink': 'http://en.wikipedia.org/Category:Respiratory_diseases', 'score': 1, 'wikidataId': 'Q3286546'}, {'id': 4, 'label': 'Lung', 'wikiLink': 'http://en.wikipedia.org/Category:Lung', 'score': 1, 'wikidataId': 'Q7886'}, {'id': 5, 'label': 'Medical specialties', 'wikiLink': 'http://en.wikipedia.org/Category:Medical_specialties', 'score': 1, 'wikidataId': 'Q930752'}, {'id': 6, 'label': 'Pulmonology', 'wikiLink': 'http://en.wikipedia.org/Category:Pulmonology', 'score': 1, 'wikidataId': 'Q203337'}, {'id': 7, 'label': 'Respiratory system', 'wikiLink': 'http://en.wikipedia.org/Category:Respiratory_system', 'score': 1, 'wikidataId': 'Q7891'}, {'id': 8, 'label': 'Organs (anatomy)', 'wikiLink': 'http://en.wikipedia.org/Category:Organs_(anatomy)', 'score': 1, 'wikidataId': 'Q712378'}, {'id': 9, 'label': 'Health', 'wikiLink': 'http://en.wikipedia.org/Category:Health', 'score': 1, 'wikidataId': 'Q12147'}, {'id': 10, 'label': 'Lower respiratory tract diseases', 'wikiLink': 'http://en.wikipedia.org/Category:Lower_respiratory_tract_diseases', 'score': 0.9837, 'wikidataId': 'Q18553224'}, {'id': 11, 'label': 'Lung disorders', 'wikiLink': 'http://en.wikipedia.org/Category:Lung_disorders', 'score': ...
# {'_id': ObjectId('5ec8066f656ebc99880e73af'), 'url': 'https://vrtnws.be/p.7RZdQNvjj', 'date': datetime.datetime(2020, 5, 22, 16, 55), 'meta': {'source': {'name': 'vrt.be', 'feed_url': 'https://www.vrt.be/vrtnws/nl.rss.articles.xml', 'feed_title': 'articles', 'country': 'BE', 'language': 'nl'}, 'feedparser': {'title': 'LIVE : Het Journaal met VGT', 'summary': 'Volg live Het Journaal met Vlaamse Gebarentaal.', 'published_parsed': datetime.datetime(2020, 5, 22, 16, 55)}, 'newspaper3k': {'authors': ['Vrt Nws'], 'summary': '', 'top_image': 'https://images.vrt.be/vrtnws_share/2019/02/12/b2a1aa0e-2edd-11e9-abcc-02b7b76bf47f.jpg', 'date': datetime.datetime(2020, 5, 22, 16, 55)}}, 'text': 'Ook dat nog Brit zoekt nieuwe hond en vindt… eigen hond', 'title': 'LIVE : Het Journaal met VGT', 'textrazor_response': {'response': {'language': 'dut', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Dogs', 'wikiLink': 'http://en.wikipedia.org/Category:Dogs', 'score': 0.08599, 'wikidataId': 'Q144'}, {'id': 1, 'label': 'Subspecies of Canis lupus', 'wikiLink': 'http://en.wikipedia.org/Category:Subspecies_of_Canis_lupus', 'score': 0.07293}, {'id': 2, 'label': 'Animals kept as pets', 'wikiLink': 'http://en.wikipedia.org/Category:Animals_kept_as_pets', 'score': 0.06698}, {'id': 3, 'label': 'Domesticated animals', 'wikiLink': 'http://en.wikipedia.org/Category:Domesticated_animals', 'score': 0.05471, 'wikidataId': 'Q622852'}], 'entities': [{'id': 0, 'type': ['Place'], 'matchingTokens': [3], 'entityId': 'Brit', 'freebaseTypes': ['/location/location'], 'confidenceScore': 0.5, 'wikiLink': '', 'matchedText': 'Brit', 'relevanceScore': 0, 'entityEnglishId': '', 'startingPos': 12, 'endingPos': 16}]}, 'time': 0.01012, 'ok': True}}
# {'_id': ObjectId('5ec8066fac7298b94a3cf3ba'), 'url': 'https://vrtnws.be/p.WWY9xP9jx', 'date': datetime.datetime(2020, 5, 22, 15, 30, 49), 'meta': {'source': {'name': 'vrt.be', 'feed_url': 'https://www.vrt.be/vrtnws/nl.rss.headlines.xml', 'feed_title': 'headlines', 'country': 'BE', 'language': 'nl'}, 'feedparser': {'title': 'Advies na onderwijsoverleg: kleuterscholen opnieuw open vanaf 2 juni, meer leerlingen op school in lager en middelbaar', 'summary': 'Vanaf 2 juni het kleuteronderwijs heropenen en meer leerlingen terug naar school laten gaan in het lager en het secundair onderwijs. Dat zijn Vlaams minister van Onderwijs Ben Weyts (N-VA), de onderwijskoepels en de vakbonden overeengekomen na urenlang overleg. Het gaat om een advies, de Nationale Veiligheidsraad moet nog het licht op groen zetten.', 'published_parsed': datetime.datetime(2020, 5, 22, 15, 30, 49)}, 'newspaper3k': {'authors': ['Vrt Nws', 'Joris Truyts', 'Minister Van Onderwijs Ben Weyts', 'N-Va'], 'summary': '', 'top_image': 'https://images.vrt.be/vrtnws_share/2020/05/15/c7e07827-969d-11ea-aae0-02b7b76bf47f.jpg', 'date': datetime.datetime(2020, 5, 22, 15, 30)}}, 'text': 'Na een lange vergadering hebben minister Weyts en de onderwijsinstanties beslist om op die vragen in te gaan. Zo adviseren ze om het kleuteronderwijs volledig te heropenen vanaf 2 juni en is het de bedoeling om in het lager onderwijs de leerlingen minstens de helft van de onderwijstijd op school te laten doorbrengen. De scholen mogen hierbij zelf kijken hoe ze dat precies invullen.\n\nVoor de kleuters zullen geen afstandsregels gelden. In het lager en het secundair onderwijs blijft afstand houden wel de regel.\n\nVanaf 2 juni mogen in het secundair onderwijs de leerlingen van het tweede en vierde jaar de lessen op school hervatten, aldus het advies. De leerlingen komen gedurende maximaal 2 volle dagen of 4 halve dagen per week naar school. Het is de bedoeling om het eerste, derde en vijfde jaar ten minste nog één dag naar school te laten komen.\n\nOok het buitengewoon onderwijs mag verder opstarten. "Ook hier ligt de autonomie bij de scholen om in de mate van het mogelijke en ook gelet op eventuele beperkingen op vlak van leerlingenvervoer keuzes te maken", zo staat in het advies.', 'title': 'Advies na onderwijsoverleg: kleuterscholen opnieuw open vanaf 2 juni, meer leerlingen op school in lager en middelbaar', 'textrazor_response': {'response': {'coarseTopics': [{'id': 0, 'label': 'Culture', 'wikiLink': 'http://en.wikipedia.org/Category:Culture', 'score': 1}, {'id': 1, 'label': 'Politics', 'wikiLink': 'http://en.wikipedia.org/Category:Politics', 'score': 0.8695}, {'id': 2, 'label': 'Education', 'wikiLink': 'http://en.wikipedia.org/Category:Education', 'score': 0.6339}, {'id': 3, 'label': 'Science', 'wikiLink': 'http://en.wikipedia.org/Category:Science', 'score': 0.4554}, {'id': 4, 'label': 'Law', 'wikiLink': 'http://en.wikipedia.org/Category:Law', 'score': 0.4325}, {'id': 5, 'label': 'Leisure', 'wikiLink': 'http://en.wikipedia.org/Category:Leisure', 'score': 0.292}], 'language': 'dut', 'languageIsReliable': True, 'topics': [{'id': 0, 'label': 'Human activities', 'wikiLink': 'http://en.wikipedia.org/Category:Human_activities', 'score': 1}, {'id': 1, 'label': 'Education', 'wikiLink': 'http://en.wikipedia.org/Category:Education', 'score': 0.8383, 'wikidataId': 'Q8434'}, {'id': 2, 'label': 'Kindergarten', 'wikiLink': 'http://en.wikipedia.org/Kindergarten', 'score': 0.7953, 'wikidataId': 'Q126807'}, {'id': 3, 'label': 'Culture', 'wikiLink': 'http://en.wikipedia.org/Category:Culture', 'score': 0.7568, 'wikidataId': 'Q11042'}, {'id': 4, 'label': 'Behavior modification', 'wikiLink': 'http://en.wikipedia.org/Category:Behavior_modification', 'score': 0.6768, 'wikidataId': 'Q2883473'}, {'id': 5, 'label': 'Learning', 'wikiLink': 'http://en.wikipedia.org/Category:Learning', 'score': 0.6751, 'wikidataId': 'Q133500'}, {'id': 6, 'label': 'Social institutions', 'wikiLink': 'http://en.wikipedia.org/Category:Soci ...
